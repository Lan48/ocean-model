# %%
## import packages
import torch
import numpy as np
import xarray as xr
from model import ORCADLConfig, ORCADLModel

# %%
import torch.nn as nn
import copy as _py_copy

class ResidualModule(nn.Module):
    def __init__(self, orig: nn.Module, copy_mod: nn.Module):
        super().__init__()
        self.orig = orig
        self.copy = copy_mod

    def forward(self, *args, **kwargs):
        # assume original and copy have compatible signatures
        out_orig = self.orig(*args, **kwargs)
        out_copy = self.copy(*args, **kwargs)
        return out_orig + out_copy

class ResidualModule(nn.Module):
    def __init__(self, orig: nn.Module, copy_mod: nn.Module):
        super().__init__()
        self.orig = orig
        self.copy = copy_mod

    def forward(self, *args, **kwargs):
        # assume original and copy have compatible signatures
        out_orig = self.orig(*args, **kwargs)
        out_copy = self.copy(*args, **kwargs)
        return out_orig + out_copy


def _reinit_module_randomly(mod: nn.Module):
    # Try to call reset_parameters for submodules; fallback to common inits
    for m in mod.modules():
        if hasattr(m, 'reset_parameters'):
            try:
                m.reset_parameters()
            except Exception:
                pass

    # For any parameters left, apply a reasonable default init
    for p in mod.parameters():
        if p.data.numel() == 0:
            continue
        if p.data.ndim > 1:
            nn.init.xavier_uniform_(p.data)
        else:
            nn.init.zeros_(p.data)


def freeze_and_add_residual_copies(model: nn.Module):
    """Freeze original parameters and append a randomly-initialized copy as a residual
    for every child module that has parameters. The copy's last nn.Linear has weight
    and bias set to zero so the residual starts from zero.
    """
    # Freeze all original params first
    for p in model.parameters():
        p.requires_grad = False

    def process(parent: nn.Module):
        # collect names to avoid runtime mutation issues
        for name, child in list(parent.named_children()):
            # Recurse into child first so deep copies reflect internal wrappers
            process(child)

            # Only consider modules that contain parameters (leaf or containers)
            has_params = any(True for _ in child.parameters())
            if not has_params:
                continue

            # Avoid wrapping if already a ResidualModule
            if isinstance(child, ResidualModule):
                continue

            # Prefer re-instantiating the module (no-arg constructor) first.
            # If that fails (custom __init__ requires args), fall back to deepcopy.
            try:
                copy_mod = child.__class__()
                _reinit_module_randomly(copy_mod)
            except Exception:
                copy_mod = _py_copy.deepcopy(child)
                _reinit_module_randomly(copy_mod)

            # Find last Linear in copy_mod and zero its params
            linears = [m for m in copy_mod.modules() if isinstance(m, nn.Linear)]
            if len(linears) > 0:
                last_lin = linears[-1]
                if hasattr(last_lin, 'weight') and last_lin.weight is not None:
                    last_lin.weight.data.zero_()
                if hasattr(last_lin, 'bias') and last_lin.bias is not None:
                    last_lin.bias.data.zero_()

            # Ensure copied module params are trainable
            for p in copy_mod.parameters():
                p.requires_grad = True

            # Wrap original child and the copy in a residual block
            wrapped = ResidualModule(child, copy_mod)
            setattr(parent, name, wrapped)

    process(model)

# %%
## Download the contents in stat and ckpt folder

## Prepare input data

# salinity, potential temp, sea surface temp, zonal current, meridional current, sea surface height, zonal wind stress, meridional wind stress
variables = ['salt', 'pottmp', 'sst', 'ucur', 'vcur', 'sshg', 'uflx', 'vflx'] 

# load mean and std
stat = {
    'mean': {v: np.load(f"./stat/mean/{v}.npy") for v in variables},
    'std': {v: np.load(f"./stat/std/{v}.npy") for v in variables}
}
## Note: the unit for temperatue is °C, salinity is g/kg, current is m/s, ssh is m, wind stress is N/m²
for v in variables:
    a =np.load(f"./stat/mean/{v}.npy") 
# load data
month = 0  # the corresponding statistical values ​​for each month are different
ocean_vars = []
atmo_vars = []
for v in variables[:-2]:
    ds = xr.open_dataset(f"./example_data/{v}.nc")
    # Important: the units of input data should be consistent with the units of the statistical values
    normed_data = (ds[v].values - stat['mean'][v][month]) / stat['std'][v][month]
    ocean_vars.append(normed_data if len(normed_data.shape) == 3 else normed_data[None])
for v in variables[-2:]:
    ds = xr.open_dataset(f"./example_data/{v}.nc")
    print(v)
    print("=== 所有变量的形状信息 ===")
    for var_name, da in ds.data_vars.items():
        print(f"变量 {var_name} 的形状：{da.shape}")
    normed_data = (ds[v].values - stat['mean'][v][month]) / stat['std'][v][month]
    atmo_vars.append(normed_data[None])

device = 'cuda' if torch.cuda.is_available() else 'cpu'

print(f"Using device: {device}")
ocean_vars = torch.from_numpy(np.nan_to_num(np.concatenate(ocean_vars, axis=0)))[None].float().to(device) # (1, 66, 128, 360)
atmo_vars = torch.from_numpy(np.nan_to_num(np.concatenate(atmo_vars, axis=0)))[None].float().to(device) # (1, 2, 128, 360)

print(ocean_vars.shape, atmo_vars.shape)
# Out:
# uflx
# === 所有变量的形状信息 ===
# 变量 uflx 的形状：(128, 360)
# vflx
# === 所有变量的形状信息 ===
# 变量 vflx 的形状：(128, 360)
# Using device: cuda
# torch.Size([1, 66, 128, 360]) torch.Size([1, 2, 128, 360])

# %%
## Setup ORCA-DL
model = ORCADLModel(ORCADLConfig.from_json_file('./model_config.json'))
model.load_state_dict(torch.load('./ckpt/seed_1.bin', map_location='cpu'))
model.to(device)
model.eval()
# Out:
# /root/miniconda3/envs/orca/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ORCADLModel(
#   (enc_ocean): OceanEncoders(
#     (encoder_list): ModuleList(
#       (0-1): 2 x EncoderModule(
#         (patch_embed): PatchEmbed(
#           (proj): Conv2d(16, 96, kernel_size=(2, 3), stride=(2, 3))
#           (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#         )
#         (pos_drop): Dropout(p=0.0, inplace=False)
#         (stages): ModuleList(
#           (0): SwinEncoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=96, out_features=288, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): Identity()
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=96, out_features=288, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.040)
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (downsample): PatchMerging(
#               (reduction): Linear(in_features=384, out_features=192, bias=False)
#               (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (1): SwinEncoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.080)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.120)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (downsample): PatchMerging(
#               (reduction): Linear(in_features=768, out_features=384, bias=False)
#               (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (2): SwinEncoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.160)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.200)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#         (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): EncoderModule(
#         (patch_embed): PatchEmbed(
#           (proj): Conv2d(1, 96, kernel_size=(2, 3), stride=(2, 3))
#           (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#         )
#         (pos_drop): Dropout(p=0.0, inplace=False)
#         (stages): ModuleList(
#           (0): SwinEncoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=96, out_features=288, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): Identity()
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=96, out_features=288, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.040)
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (downsample): PatchMerging(
#               (reduction): Linear(in_features=384, out_features=192, bias=False)
#               (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (1): SwinEncoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.080)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.120)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (downsample): PatchMerging(
#               (reduction): Linear(in_features=768, out_features=384, bias=False)
#               (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (2): SwinEncoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.160)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.200)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#         (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       )
#       (3-4): 2 x EncoderModule(
#         (patch_embed): PatchEmbed(
#           (proj): Conv2d(16, 96, kernel_size=(2, 3), stride=(2, 3))
#           (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#         )
#         (pos_drop): Dropout(p=0.0, inplace=False)
#         (stages): ModuleList(
#           (0): SwinEncoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=96, out_features=288, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): Identity()
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=96, out_features=288, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.040)
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (downsample): PatchMerging(
#               (reduction): Linear(in_features=384, out_features=192, bias=False)
#               (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (1): SwinEncoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.080)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.120)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (downsample): PatchMerging(
#               (reduction): Linear(in_features=768, out_features=384, bias=False)
#               (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (2): SwinEncoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.160)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.200)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#         (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): EncoderModule(
#         (patch_embed): PatchEmbed(
#           (proj): Conv2d(1, 96, kernel_size=(2, 3), stride=(2, 3))
#           (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#         )
#         (pos_drop): Dropout(p=0.0, inplace=False)
#         (stages): ModuleList(
#           (0): SwinEncoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=96, out_features=288, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): Identity()
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=96, out_features=288, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.040)
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (downsample): PatchMerging(
#               (reduction): Linear(in_features=384, out_features=192, bias=False)
#               (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (1): SwinEncoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.080)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.120)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (downsample): PatchMerging(
#               (reduction): Linear(in_features=768, out_features=384, bias=False)
#               (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (2): SwinEncoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.160)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.200)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#         (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (proj): Linear(in_features=2304, out_features=1152, bias=True)
#   )
#   (fusion): FusionModule(
#     (stages): ModuleList(
#       (0): SwinEncoderStage(
#         (blocks): ModuleList(
#           (0): SwinLayer(
#             (norm1): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               (pos_embed): RotaryPosEmbed2D()
#               (qkv): Linear(in_features=1152, out_features=3456, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=1152, out_features=1152, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): Identity()
#             (norm2): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
#             (mlp): MlpMoe(
#               (mlps): ModuleList(
#                 (0-5): 6 x Mlp(
#                   (fc1): Linear(in_features=1152, out_features=4608, bias=True)
#                   (act): GELUActivation()
#                   (fc2): Linear(in_features=4608, out_features=1152, bias=True)
#                   (drop): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#           )
#           (1): SwinLayer(
#             (norm1): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               (pos_embed): RotaryPosEmbed2D()
#               (qkv): Linear(in_features=1152, out_features=3456, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=1152, out_features=1152, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath(drop_prob=0.067)
#             (norm2): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
#             (mlp): MlpMoe(
#               (mlps): ModuleList(
#                 (0-5): 6 x Mlp(
#                   (fc1): Linear(in_features=1152, out_features=4608, bias=True)
#                   (act): GELUActivation()
#                   (fc2): Linear(in_features=4608, out_features=1152, bias=True)
#                   (drop): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (1): SwinEncoderStage(
#         (blocks): ModuleList(
#           (0): SwinLayer(
#             (norm1): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               (pos_embed): RotaryPosEmbed2D()
#               (qkv): Linear(in_features=1152, out_features=3456, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=1152, out_features=1152, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath(drop_prob=0.133)
#             (norm2): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
#             (mlp): MlpMoe(
#               (mlps): ModuleList(
#                 (0-5): 6 x Mlp(
#                   (fc1): Linear(in_features=1152, out_features=4608, bias=True)
#                   (act): GELUActivation()
#                   (fc2): Linear(in_features=4608, out_features=1152, bias=True)
#                   (drop): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#           )
#           (1): SwinLayer(
#             (norm1): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               (pos_embed): RotaryPosEmbed2D()
#               (qkv): Linear(in_features=1152, out_features=3456, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=1152, out_features=1152, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath(drop_prob=0.200)
#             (norm2): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
#             (mlp): MlpMoe(
#               (mlps): ModuleList(
#                 (0-5): 6 x Mlp(
#                   (fc1): Linear(in_features=1152, out_features=4608, bias=True)
#                   (act): GELUActivation()
#                   (fc2): Linear(in_features=4608, out_features=1152, bias=True)
#                   (drop): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (pos_drop): Dropout(p=0.0, inplace=False)
#     (rotate_atmo): RotaryTimeEmbed()
#   )
#   (dec_ocean): OceanDecoders(
#     (decoder_list): ModuleList(
#       (0-1): 2 x DecoderModule(
#         (stages): ModuleList(
#           (0): SwinDecoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.200)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.160)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (upsample): PatchExpanding(
#               (expand): Linear(in_features=384, out_features=768, bias=False)
#               (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (1): SwinDecoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.120)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.080)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (upsample): PatchExpanding(
#               (expand): Linear(in_features=192, out_features=384, bias=False)
#               (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (2): SwinDecoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=96, out_features=288, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.040)
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=96, out_features=288, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): Identity()
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#         (concat_proj_layers): ModuleList(
#           (0): Linear(in_features=384, out_features=192, bias=True)
#           (1): Linear(in_features=192, out_features=96, bias=True)
#         )
#         (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#         (final_proj): ConvTranspose2d(96, 16, kernel_size=(2, 3), stride=(2, 3))
#       )
#       (2): DecoderModule(
#         (stages): ModuleList(
#           (0): SwinDecoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.200)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.160)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (upsample): PatchExpanding(
#               (expand): Linear(in_features=384, out_features=768, bias=False)
#               (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (1): SwinDecoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.120)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
# ...
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): Identity()
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#         (concat_proj_layers): ModuleList(
#           (0): Linear(in_features=384, out_features=192, bias=True)
#           (1): Linear(in_features=192, out_features=96, bias=True)
#         )
#         (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#         (final_proj): ConvTranspose2d(96, 16, kernel_size=(2, 3), stride=(2, 3))
#       )
#       (5): DecoderModule(
#         (stages): ModuleList(
#           (0): SwinDecoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.200)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=384, out_features=384, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.160)
#                 (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (upsample): PatchExpanding(
#               (expand): Linear(in_features=384, out_features=768, bias=False)
#               (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (1): SwinDecoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.120)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=192, out_features=576, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=192, out_features=192, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.080)
#                 (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=192, out_features=768, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=768, out_features=192, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#             (upsample): PatchExpanding(
#               (expand): Linear(in_features=192, out_features=384, bias=False)
#               (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (2): SwinDecoderStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=96, out_features=288, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): DropPath(drop_prob=0.040)
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#               (1): SwinLayer(
#                 (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (attn): WindowAttention(
#                   (pos_embed): RotaryPosEmbed2D()
#                   (qkv): Linear(in_features=96, out_features=288, bias=True)
#                   (attn_drop): Dropout(p=0.0, inplace=False)
#                   (proj): Linear(in_features=96, out_features=96, bias=True)
#                   (proj_drop): Dropout(p=0.0, inplace=False)
#                   (softmax): Softmax(dim=-1)
#                 )
#                 (drop_path): Identity()
#                 (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#                 (mlp): MlpMoe(
#                   (mlps): ModuleList(
#                     (0-5): 6 x Mlp(
#                       (fc1): Linear(in_features=96, out_features=384, bias=True)
#                       (act): GELUActivation()
#                       (fc2): Linear(in_features=384, out_features=96, bias=True)
#                       (drop): Dropout(p=0.0, inplace=False)
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#         (concat_proj_layers): ModuleList(
#           (0): Linear(in_features=384, out_features=192, bias=True)
#           (1): Linear(in_features=192, out_features=96, bias=True)
#         )
#         (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#         (final_proj): ConvTranspose2d(96, 1, kernel_size=(2, 3), stride=(2, 3))
#       )
#     )
#     (proj): Linear(in_features=1152, out_features=2304, bias=True)
#   )
#   (enc_atmo): AtmoEncoder(
#     (encoder): EncoderModule(
#       (patch_embed): PatchEmbed(
#         (proj): Conv2d(2, 96, kernel_size=(2, 3), stride=(2, 3))
#         (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#       )
#       (pos_drop): Dropout(p=0.0, inplace=False)
#       (stages): ModuleList(
#         (0): SwinEncoderStage(
#           (blocks): ModuleList(
#             (0): SwinLayer(
#               (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#               (attn): WindowAttention(
#                 (pos_embed): RotaryPosEmbed2D()
#                 (qkv): Linear(in_features=96, out_features=288, bias=True)
#                 (attn_drop): Dropout(p=0.0, inplace=False)
#                 (proj): Linear(in_features=96, out_features=96, bias=True)
#                 (proj_drop): Dropout(p=0.0, inplace=False)
#                 (softmax): Softmax(dim=-1)
#               )
#               (drop_path): Identity()
#               (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#               (mlp): Mlp(
#                 (fc1): Linear(in_features=96, out_features=384, bias=True)
#                 (act): GELUActivation()
#                 (fc2): Linear(in_features=384, out_features=96, bias=True)
#                 (drop): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (1): SwinLayer(
#               (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#               (attn): WindowAttention(
#                 (pos_embed): RotaryPosEmbed2D()
#                 (qkv): Linear(in_features=96, out_features=288, bias=True)
#                 (attn_drop): Dropout(p=0.0, inplace=False)
#                 (proj): Linear(in_features=96, out_features=96, bias=True)
#                 (proj_drop): Dropout(p=0.0, inplace=False)
#                 (softmax): Softmax(dim=-1)
#               )
#               (drop_path): DropPath(drop_prob=0.040)
#               (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#               (mlp): Mlp(
#                 (fc1): Linear(in_features=96, out_features=384, bias=True)
#                 (act): GELUActivation()
#                 (fc2): Linear(in_features=384, out_features=96, bias=True)
#                 (drop): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#           (downsample): PatchMerging(
#             (reduction): Linear(in_features=384, out_features=192, bias=False)
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): SwinEncoderStage(
#           (blocks): ModuleList(
#             (0): SwinLayer(
#               (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (attn): WindowAttention(
#                 (pos_embed): RotaryPosEmbed2D()
#                 (qkv): Linear(in_features=192, out_features=576, bias=True)
#                 (attn_drop): Dropout(p=0.0, inplace=False)
#                 (proj): Linear(in_features=192, out_features=192, bias=True)
#                 (proj_drop): Dropout(p=0.0, inplace=False)
#                 (softmax): Softmax(dim=-1)
#               )
#               (drop_path): DropPath(drop_prob=0.080)
#               (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (mlp): Mlp(
#                 (fc1): Linear(in_features=192, out_features=768, bias=True)
#                 (act): GELUActivation()
#                 (fc2): Linear(in_features=768, out_features=192, bias=True)
#                 (drop): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (1): SwinLayer(
#               (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (attn): WindowAttention(
#                 (pos_embed): RotaryPosEmbed2D()
#                 (qkv): Linear(in_features=192, out_features=576, bias=True)
#                 (attn_drop): Dropout(p=0.0, inplace=False)
#                 (proj): Linear(in_features=192, out_features=192, bias=True)
#                 (proj_drop): Dropout(p=0.0, inplace=False)
#                 (softmax): Softmax(dim=-1)
#               )
#               (drop_path): DropPath(drop_prob=0.120)
#               (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (mlp): Mlp(
#                 (fc1): Linear(in_features=192, out_features=768, bias=True)
#                 (act): GELUActivation()
#                 (fc2): Linear(in_features=768, out_features=192, bias=True)
#                 (drop): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#           (downsample): PatchMerging(
#             (reduction): Linear(in_features=768, out_features=384, bias=False)
#             (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): SwinEncoderStage(
#           (blocks): ModuleList(
#             (0): SwinLayer(
#               (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attn): WindowAttention(
#                 (pos_embed): RotaryPosEmbed2D()
#                 (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                 (attn_drop): Dropout(p=0.0, inplace=False)
#                 (proj): Linear(in_features=384, out_features=384, bias=True)
#                 (proj_drop): Dropout(p=0.0, inplace=False)
#                 (softmax): Softmax(dim=-1)
#               )
#               (drop_path): DropPath(drop_prob=0.160)
#               (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (mlp): Mlp(
#                 (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                 (act): GELUActivation()
#                 (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                 (drop): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (1): SwinLayer(
#               (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (attn): WindowAttention(
#                 (pos_embed): RotaryPosEmbed2D()
#                 (qkv): Linear(in_features=384, out_features=1152, bias=True)
#                 (attn_drop): Dropout(p=0.0, inplace=False)
#                 (proj): Linear(in_features=384, out_features=384, bias=True)
#                 (proj_drop): Dropout(p=0.0, inplace=False)
#                 (softmax): Softmax(dim=-1)
#               )
#               (drop_path): DropPath(drop_prob=0.200)
#               (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (mlp): Mlp(
#                 (fc1): Linear(in_features=384, out_features=1536, bias=True)
#                 (act): GELUActivation()
#                 (fc2): Linear(in_features=1536, out_features=384, bias=True)
#                 (drop): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#         )
#       )
#       (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     )
#     (proj): Linear(in_features=384, out_features=1152, bias=True)
#   )
# )

# %%
from netCDF4 import Dataset

import xarray as xr

# 1. 定义.nc文件路径（修改为你的实际文件路径）
nc_file_path = "/mnt/data/zhu.yishun/CMIP6_Data/thetao_Omon_TaiESM1_historical_r1i1p1f1_gn_201401-201412.nc"
  # 替换为你的.nc文件路径，如so_Omon_E3SM-1-0_historical_r1i1p1f1_gr_200501-200912.nc

# 2. 读取.nc文件（xarray采用懒加载，大文件也不会占用过多内存）
try:
    ds = xr.open_dataset(
        nc_file_path, 
        use_cftime=True, 
        engine='netcdf4'  # 显式指定引擎，解决之前的自动推断失败问题
    )
except FileNotFoundError:
    print("错误：未找到指定的.nc文件，请检查文件路径是否正确！")
    exit()
except Exception as e:
    print(f"错误：读取文件失败，异常信息：{e}")
    exit()

# 3. 输出.nc文件的完整结构
print("=" * 80)
print("1. .nc文件整体结构概览（维度、变量、全局属性）：")
print("=" * 80)
# info() 方法输出核心结构信息，包括维度、变量、数据类型、属性等
ds.info()

print("\n" + "=" * 80)
print("2. 详细维度信息：")
print("=" * 80)
# 输出所有维度（名称、大小）
for dim_name, dim_size in ds.dims.items():
    print(f"维度名称：{dim_name}，维度大小：{dim_size}")

print("\n" + "=" * 80)
print("3. 详细变量信息：")
print("=" * 80)
# 输出所有变量（名称、维度、数据类型、属性）
for var_name, var_data in ds.variables.items():
    print(f"变量名称：{var_name}")
    print(f"  - 变量维度：{list(var_data.dims)}")
    print(f"  - 变量形状：{var_data.shape}")
    print(f"  - 数据类型：{var_data.dtype}")
    print(f"  - 变量属性：{dict(var_data.attrs)}")
    print("-" * 40)

print("\n" + "=" * 80)
print("4. 全局属性信息（文件描述、来源等）：")
print("=" * 80)
for attr_name, attr_value in ds.attrs.items():
    print(f"{attr_name}：{attr_value}")

# 4. 关闭数据集（释放资源，可选，xarray会自动管理）
ds.close()
# Out:
# ================================================================================
# 1. .nc文件整体结构概览（维度、变量、全局属性）：
# ================================================================================
# xarray.Dataset {
# dimensions:
# 	time = 12 ;
# 	bnds = 2 ;
# 	lev = 60 ;
# 	j = 384 ;
# 	i = 320 ;
# 	vertices = 4 ;
#
# variables:
# 	object time(time) ;
# 		time:bounds = time_bnds ;
# 		time:axis = T ;
# 		time:long_name = time ;
# 		time:standard_name = time ;
# 	object time_bnds(time, bnds) ;
# 	float64 lev(lev) ;
# 		lev:bounds = lev_bnds ;
# 		lev:units = m ;
# 		lev:axis = Z ;
# 		lev:positive = down ;
# 		lev:long_name = ocean depth coordinate ;
# 		lev:standard_name = depth ;
# 	float64 lev_bnds(lev, bnds) ;
# 	int32 j(j) ;
# 		j:units = 1 ;
# 		j:long_name = cell index along second dimension ;
# 	int32 i(i) ;
# 		i:units = 1 ;
# 		i:long_name = cell index along first dimension ;
# 	float64 latitude(j, i) ;
# 		latitude:standard_name = latitude ;
# 		latitude:long_name = latitude ;
# 		latitude:units = degrees_north ;
# 		latitude:bounds = vertices_latitude ;
# 	float64 longitude(j, i) ;
# 		longitude:standard_name = longitude ;
# 		longitude:long_name = longitude ;
# 		longitude:units = degrees_east ;
# 		longitude:bounds = vertices_longitude ;
# 	float64 vertices_latitude(j, i, vertices) ;
# 		vertices_latitude:units = degrees_north ;
# 	float64 vertices_longitude(j, i, vertices) ;
# 		vertices_longitude:units = degrees_east ;
# 	float32 thetao(time, lev, j, i) ;
# 		thetao:standard_name = sea_water_potential_temperature ;
# 		thetao:long_name = Sea Water Potential Temperature ;
# 		thetao:comment = Diagnostic should be contributed even for models using conservative temperature as prognostic field. ;
# 		thetao:units = degC ;
# 		thetao:original_name = TEMP ;
# 		thetao:cell_methods = area: mean where sea time: mean ;
# 		thetao:cell_measures = area: areacello volume: volcello ;
# 		thetao:history = 2020-06-15T04:38:29Z altered by CMOR: replaced missing value flag (9.96921e+36) and corresponding data with standard missing value (1e+20). ;
#
# // global attributes:
# 	:Conventions = CF-1.7 CMIP-6.2 ;
# 	:activity_id = CMIP ;
# 	:branch_method = Hybrid-restart from year 0671-01-01 of piControl ;
# 	:branch_time_in_child = 0.0 ;
# 	:branch_time_in_parent = 171550.0 ;
# 	:contact = Dr. Wei-Liang Lee (leelupin@gate.sinica.edu.tw) ;
# 	:creation_date = 2020-06-15T04:38:29Z ;
# 	:data_specs_version = 01.00.31 ;
# 	:experiment = all-forcing simulation of the recent past ;
# 	:experiment_id = historical ;
# 	:external_variables = areacello volcello ;
# 	:forcing_index = 1 ;
# 	:frequency = mon ;
# 	:further_info_url = https://furtherinfo.es-doc.org/CMIP6.AS-RCEC.TaiESM1.historical.none.r1i1p1f1 ;
# 	:grid = finite-volume grid with 0.9x1.25 degree lat/lon resolution ;
# 	:grid_label = gn ;
# 	:history = 2020-06-15T04:38:29Z ; CMOR rewrote data to be consistent with CMIP6, CF-1.7 CMIP-6.2 and CF standards. ;
# 	:initialization_index = 1 ;
# 	:institution = Research Center for Environmental Changes, Academia Sinica, Nankang, Taipei 11529, Taiwan ;
# 	:institution_id = AS-RCEC ;
# 	:mip_era = CMIP6 ;
# 	:nominal_resolution = 100 km ;
# 	:parent_activity_id = CMIP ;
# 	:parent_experiment_id = piControl ;
# 	:parent_mip_era = CMIP6 ;
# 	:parent_source_id = TaiESM1 ;
# 	:parent_time_units = days since 1850-01-01 ;
# 	:parent_variant_label = r1i1p1f1 ;
# 	:physics_index = 1 ;
# 	:product = model-output ;
# 	:realization_index = 1 ;
# 	:realm = ocean ;
# 	:references = 10.5194/gmd-2019-377 ;
# 	:source = TaiESM 1.0 (2018):
# aerosol: SNAP (same grid as atmos)
# atmos: TaiAM1 (0.9x1.25 degree; 288 x 192 longitude/latitude; 30 levels; top level ~2 hPa)
# atmosChem: SNAP (same grid as atmos)
# land: CLM4.0 (same grid as atmos)
# landIce: none
# ocean: POP2 (320x384 longitude/latitude; 60 levels; top grid cell 0-10 m)
# ocnBgchem: none
# seaIce: CICE4 ;
# 	:source_id = TaiESM1 ;
# 	:source_type = AOGCM AER BGC ;
# 	:sub_experiment = none ;
# 	:sub_experiment_id = none ;
# 	:table_id = Omon ;
# 	:table_info = Creation Date:(24 July 2019) MD5:0bb394a356ef9d214d027f1aca45853e ;
# 	:title = TaiESM1 output prepared for CMIP6 ;
# 	:variable_id = thetao ;
# 	:variant_label = r1i1p1f1 ;
# 	:license = CMIP6 model data produced by REQUIRED is licensed under a Creative Commons Attribution ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law. ;
# 	:cmor_version = 3.5.0 ;
# 	:tracking_id = hdl:21.14100/e9161761-2d56-401f-b287-5da850b0f17e ;
# }
# ================================================================================
# 2. 详细维度信息：
# ================================================================================
# 维度名称：time，维度大小：12
# 维度名称：bnds，维度大小：2
# 维度名称：lev，维度大小：60
# 维度名称：j，维度大小：384
# 维度名称：i，维度大小：320
# 维度名称：vertices，维度大小：4
#
# ================================================================================
# 3. 详细变量信息：
# ================================================================================
# 变量名称：time
#   - 变量维度：['time']
#   - 变量形状：(12,)
#   - 数据类型：object
#   - 变量属性：{'bounds': 'time_bnds', 'axis': 'T', 'long_name': 'time', 'standard_name': 'time'}
# ----------------------------------------
# 变量名称：time_bnds
#   - 变量维度：['time', 'bnds']
#   - 变量形状：(12, 2)
#   - 数据类型：object
#   - 变量属性：{}
# ----------------------------------------
# 变量名称：lev
#   - 变量维度：['lev']
#   - 变量形状：(60,)
#   - 数据类型：float64
#   - 变量属性：{'bounds': 'lev_bnds', 'units': 'm', 'axis': 'Z', 'positive': 'down', 'long_name': 'ocean depth coordinate', 'standard_name': 'depth'}
# ----------------------------------------
# 变量名称：lev_bnds
#   - 变量维度：['lev', 'bnds']
#   - 变量形状：(60, 2)
#   - 数据类型：float64
#   - 变量属性：{}
# ----------------------------------------
# 变量名称：j
#   - 变量维度：['j']
#   - 变量形状：(384,)
#   - 数据类型：int32
#   - 变量属性：{'units': '1', 'long_name': 'cell index along second dimension'}
# ----------------------------------------
# 变量名称：i
#   - 变量维度：['i']
#   - 变量形状：(320,)
#   - 数据类型：int32
#   - 变量属性：{'units': '1', 'long_name': 'cell index along first dimension'}
# ----------------------------------------
# 变量名称：latitude
#   - 变量维度：['j', 'i']
#   - 变量形状：(384, 320)
#   - 数据类型：float64
#   - 变量属性：{'standard_name': 'latitude', 'long_name': 'latitude', 'units': 'degrees_north', 'bounds': 'vertices_latitude'}
# ----------------------------------------
# 变量名称：longitude
#   - 变量维度：['j', 'i']
#   - 变量形状：(384, 320)
#   - 数据类型：float64
#   - 变量属性：{'standard_name': 'longitude', 'long_name': 'longitude', 'units': 'degrees_east', 'bounds': 'vertices_longitude'}
# ----------------------------------------
# 变量名称：vertices_latitude
#   - 变量维度：['j', 'i', 'vertices']
#   - 变量形状：(384, 320, 4)
#   - 数据类型：float64
#   - 变量属性：{'units': 'degrees_north'}
# ----------------------------------------
# 变量名称：vertices_longitude
#   - 变量维度：['j', 'i', 'vertices']
#   - 变量形状：(384, 320, 4)
#   - 数据类型：float64
#   - 变量属性：{'units': 'degrees_east'}
# ----------------------------------------
# 变量名称：thetao
#   - 变量维度：['time', 'lev', 'j', 'i']
#   - 变量形状：(12, 60, 384, 320)
#   - 数据类型：float32
#   - 变量属性：{'standard_name': 'sea_water_potential_temperature', 'long_name': 'Sea Water Potential Temperature', 'comment': 'Diagnostic should be contributed even for models using conservative temperature as prognostic field.', 'units': 'degC', 'original_name': 'TEMP', 'cell_methods': 'area: mean where sea time: mean', 'cell_measures': 'area: areacello volume: volcello', 'history': '2020-06-15T04:38:29Z altered by CMOR: replaced missing value flag (9.96921e+36) and corresponding data with standard missing value (1e+20).'}
# ----------------------------------------
#
# ================================================================================
# 4. 全局属性信息（文件描述、来源等）：
# ================================================================================
# Conventions：CF-1.7 CMIP-6.2
# activity_id：CMIP
# branch_method：Hybrid-restart from year 0671-01-01 of piControl
# branch_time_in_child：0.0
# branch_time_in_parent：171550.0
# contact：Dr. Wei-Liang Lee (leelupin@gate.sinica.edu.tw)
# creation_date：2020-06-15T04:38:29Z
# data_specs_version：01.00.31
# experiment：all-forcing simulation of the recent past
# experiment_id：historical
# external_variables：areacello volcello
# forcing_index：1
# frequency：mon
# further_info_url：https://furtherinfo.es-doc.org/CMIP6.AS-RCEC.TaiESM1.historical.none.r1i1p1f1
# grid：finite-volume grid with 0.9x1.25 degree lat/lon resolution
# grid_label：gn
# history：2020-06-15T04:38:29Z ; CMOR rewrote data to be consistent with CMIP6, CF-1.7 CMIP-6.2 and CF standards.
# initialization_index：1
# institution：Research Center for Environmental Changes, Academia Sinica, Nankang, Taipei 11529, Taiwan
# institution_id：AS-RCEC
# mip_era：CMIP6
# nominal_resolution：100 km
# parent_activity_id：CMIP
# parent_experiment_id：piControl
# parent_mip_era：CMIP6
# parent_source_id：TaiESM1
# parent_time_units：days since 1850-01-01
# parent_variant_label：r1i1p1f1
# physics_index：1
# product：model-output
# realization_index：1
# realm：ocean
# references：10.5194/gmd-2019-377
# source：TaiESM 1.0 (2018):
# aerosol: SNAP (same grid as atmos)
# atmos: TaiAM1 (0.9x1.25 degree; 288 x 192 longitude/latitude; 30 levels; top level ~2 hPa)
# atmosChem: SNAP (same grid as atmos)
# land: CLM4.0 (same grid as atmos)
# landIce: none
# ocean: POP2 (320x384 longitude/latitude; 60 levels; top grid cell 0-10 m)
# ocnBgchem: none
# seaIce: CICE4
# source_id：TaiESM1
# source_type：AOGCM AER BGC
# sub_experiment：none
# sub_experiment_id：none
# table_id：Omon
# table_info：Creation Date:(24 July 2019) MD5:0bb394a356ef9d214d027f1aca45853e
# title：TaiESM1 output prepared for CMIP6
# variable_id：thetao
# variant_label：r1i1p1f1
# license：CMIP6 model data produced by REQUIRED is licensed under a Creative Commons Attribution ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law.
# cmor_version：3.5.0
# tracking_id：hdl:21.14100/e9161761-2d56-401f-b287-5da850b0f17e
# /tmp/ipykernel_3455943/946656632.py:11: DeprecationWarning: Usage of 'use_cftime' as a kwarg is deprecated. Please pass a 'CFDatetimeCoder' instance initialized with 'use_cftime' to the 'decode_times' kwarg instead.
# Example usage:
#     time_coder = xr.coders.CFDatetimeCoder(use_cftime=True)
#     ds = xr.open_dataset(decode_times=time_coder)
#
#   ds = xr.open_dataset(
# /tmp/ipykernel_3455943/946656632.py:34: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   for dim_name, dim_size in ds.dims.items():

# %%
## Run the model

with torch.no_grad():
    # single step
    output = model(ocean_vars=ocean_vars, atmo_vars=atmo_vars, predict_time_steps=1)
    print(output.preds.shape) # (1, 66, 128, 360)

    # Post-process the output
    preds = output.preds.detach().cpu().numpy()
    # salinity, potential temp, sea surface temp, zonal current, meridional current, sea surface height
    pred_all_variables = np.split(preds, model.split_chans, axis=1) # split by channels
    # The pred_all_variables contains the prediction of all ocaen variables and the order is the same as the input ocean variables.

    # inverse the normalization
    pred_sst = pred_all_variables[2] * stat['std']['sst'][month+1] + stat['mean']['sst'][month+1]  # stat should be the prediction month
    print(pred_sst.shape) # (1, 1, 128, 360)

    # multi steps
    steps = 6
    output = model(ocean_vars=ocean_vars, atmo_vars=atmo_vars, predict_time_steps=steps)
    print(output.preds.shape) # (1, steps, 66, 128, 360)

    # batch input
    batch_size = 4
    ocean_vars = ocean_vars.repeat(batch_size, 1, 1, 1)
    atmo_vars = atmo_vars.repeat(batch_size, 1, 1, 1)
    output = model(ocean_vars=ocean_vars, atmo_vars=atmo_vars, predict_time_steps=steps)
    print(output.preds.shape) # (batch_size, steps, 66, 128, 360)
# Out:
# torch.Size([1, 66, 128, 360])
# (1, 1, 128, 360)
# torch.Size([1, 6, 66, 128, 360])
# torch.Size([4, 6, 66, 128, 360])

# %%
print(output.preds)
# Out:
# tensor([[[[[ 1.9272e+00,  2.3122e+00,  1.8263e+00,  ...,  3.3827e+00,
#              3.1320e+00,  2.4194e+00],
#            [ 2.1823e+00,  1.6928e+00,  1.6685e+00,  ...,  1.9224e+00,
#              2.5826e+00,  2.6399e+00],
#            [ 1.4975e+00,  1.3262e+00,  1.2970e+00,  ...,  1.5088e+00,
#              2.5384e+00,  2.7330e+00],
#            ...,
#            [-2.0939e-01, -3.4817e-01, -7.2509e-01,  ...,  1.4042e+00,
#              4.8676e-01, -1.3078e-02],
#            [ 1.2945e+00,  5.5341e-01,  3.6812e-02,  ...,  1.8699e+00,
#              1.7647e+00,  1.7458e+00],
#            [ 1.4215e+00,  1.3153e+00,  1.1582e+00,  ...,  1.9882e+00,
#              1.9496e+00,  1.7924e+00]],
#
#           [[ 1.7866e+00,  2.2039e+00,  1.6755e+00,  ...,  3.3940e+00,
#              3.2009e+00,  2.4237e+00],
#            [ 2.0298e+00,  1.5219e+00,  1.5799e+00,  ...,  1.9039e+00,
#              2.5517e+00,  2.6551e+00],
#            [ 1.3904e+00,  1.2181e+00,  1.1690e+00,  ...,  1.3774e+00,
#              2.3855e+00,  2.5894e+00],
#            [ 3.2140e+00,  2.8121e+00, -9.8609e-01,  ...,  1.0790e+00,
#              2.4795e-01,  8.8376e-01]],
#
#           [[-6.6749e-01,  5.0616e-01,  1.5272e+00,  ...,  4.5297e-01,
#              6.2632e-01,  6.3791e-01],
#            [ 1.3913e+00,  1.9587e+00,  1.8934e+00,  ..., -7.3348e-02,
#              1.3926e-01,  3.7973e-01],
#            [ 6.3512e-01,  1.5710e+00,  1.5874e+00,  ..., -2.4854e+00,
#             -8.5273e-01, -8.0134e-02],
#            ...,
#            [-1.6057e-02,  4.2115e-02, -4.0025e-01,  ..., -2.5308e-01,
#             -7.5459e-02,  5.2309e-01],
#            [-8.4212e-02, -4.5661e-02, -4.2627e-01,  ...,  6.1541e-01,
#              2.2872e-01, -3.2988e-02],
#            [ 3.1140e+00,  5.0763e-01, -8.2290e-01,  ...,  1.5173e+00,
#              7.9874e-01,  1.5651e+00]],
#
#           [[ 5.7397e+00,  6.2750e+00,  6.2241e+00,  ...,  6.4133e+00,
#              5.9689e+00,  6.0855e+00],
#            [ 7.9771e+00,  8.1434e+00,  7.5365e+00,  ...,  7.4892e+00,
#              7.6387e+00,  7.4107e+00],
#            [ 7.4783e+00,  6.8574e+00,  7.2239e+00,  ...,  6.7916e+00,
#              6.7512e+00,  6.9887e+00],
#            ...,
#            [-3.2419e+00, -3.0506e+00, -8.8795e-01,  ...,  1.6130e+00,
#              3.3452e-01, -1.3223e+00],
#            [ 2.1871e+00,  1.4726e+00,  1.3286e+00,  ...,  2.5160e+00,
#              2.2433e+00,  1.7438e+00],
#            [ 3.8396e+00,  4.7619e+00,  4.5492e+00,  ...,  1.8726e+00,
#              1.8695e+00,  2.2770e+00]]]]], device='cuda:0')

# %%
model.to('cpu')
torch.cuda.empty_cache()
freeze_and_add_residual_copies(model)
model.to(device)
model.eval()

# %%
## Run the model

with torch.no_grad():
    # single step
    output = model(ocean_vars=ocean_vars, atmo_vars=atmo_vars, predict_time_steps=1)
    print(output.preds.shape) # (1, 66, 128, 360)

    # Post-process the output
    preds = output.preds.detach().cpu().numpy()
    # salinity, potential temp, sea surface temp, zonal current, meridional current, sea surface height
    pred_all_variables = np.split(preds, model.split_chans, axis=1) # split by channels
    # The pred_all_variables contains the prediction of all ocaen variables and the order is the same as the input ocean variables.

    # inverse the normalization
    pred_sst = pred_all_variables[2] * stat['std']['sst'][month+1] + stat['mean']['sst'][month+1]  # stat should be the prediction month
    print(pred_sst.shape) # (1, 1, 128, 360)

    # multi steps
    steps = 6
    output = model(ocean_vars=ocean_vars, atmo_vars=atmo_vars, predict_time_steps=steps)
    print(output.preds.shape) # (1, steps, 66, 128, 360)

    # batch input
    batch_size = 4
    ocean_vars = ocean_vars.repeat(batch_size, 1, 1, 1)
    atmo_vars = atmo_vars.repeat(batch_size, 1, 1, 1)
    output = model(ocean_vars=ocean_vars, atmo_vars=atmo_vars, predict_time_steps=steps)
    print(output.preds.shape) # (batch_size, steps, 66, 128, 360)
    print(output.preds)
